# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# Atribuição de Variaveis
site = "http://rpachallenge.com/"

arquivo = '/home/adriana/PythonADR/challenge.xlsx'

df_registros = pd.read_excel(arquivo)

print(df_registros.info())

driver = webdriver.Firefox()
print("Iniciando nosso robô...\n")
print("Acessando site...")
driver.get(site)

print('Starting...')
botao = driver.find_element(By.XPATH, "//button[@class='waves-effect col s12 m12 l12 btn-large uiColorButton']")
botao.click()
time.sleep(2)

for i, r in df_registros.iterrows():
    role = r['Role in Company']
    email = r['Email']
    first_name = r['First Name']
    last_name = r['Last Name']
    phone = r['Phone Number']
    company = r['Company Name']
    address = r['Address']

    print(first_name)

    # LOGIN
    print("Writing role...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelRole']")
    textbox.clear()
    textbox.send_keys(role)
    #time.sleep(0.5)

    print("Writing email...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelEmail']")
    textbox.clear()
    textbox.send_keys(email)
    #time.sleep(0.5)

    print("Writing first name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelFirstName']")
    textbox.clear()
    textbox.send_keys(first_name)
    #time.sleep(0.5)

    print("Writing last name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelLastName']")
    textbox.clear()
    textbox.send_keys(last_name)
    #time.sleep(0.5)

    print("Writing phone...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelPhone']")
    textbox.clear()
    textbox.send_keys(phone)
    #time.sleep(0.5)

    print("Writing address...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelAddress']")
    textbox.clear()
    textbox.send_keys(address)
    #time.sleep(0.5)

    print("Writing company...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelCompanyName']")
    textbox.clear()
    textbox.send_keys(company)
    #time.sleep(0.5)

    print('Submit...')
    botao = driver.find_element(By.XPATH, "//input[@type='submit']")
    botao.click()
    time.sleep(0.5)

print('Processo finalizado')

driver.quit()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First Name       10 non-null     object
#  1   Last Name        10 non-null     object
#  2   Company Name     10 non-null     object
#  3   Role in Company  10 non-null     object
#  4   Address          10 non-null     object
#  5   Email            10 non-null     object
#  6   Phone Number     10 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes
# None
# Iniciando nosso robô...
#
# Acessando site...
# Starting...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Last Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 29
#      27 email = r['Email']
#      28 first_name = r['First Name']
# ---> 29 last_name = r['Last Name']
#      30 phone = r['Phone Number']
#      31 company = r['Company Name']
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Last Name'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# Atribuição de Variáveis
site = "http://rpachallenge.com/"
arquivo = '/home/adriana/PythonADR/challenge.xlsx'

df_registros = pd.read_excel(arquivo)

print(df_registros.info())

driver = webdriver.Firefox()
print("Iniciando nosso robô...\n")
print("Acessando site...")
driver.get(site)

print('Starting...')
botao = driver.find_element(By.XPATH, "//button[@class='waves-effect col s12 m12 l12 btn-large uiColorButton']")
botao.click()
time.sleep(2)

for i, r in df_registros.iterrows():
    role = r['Role in Company']
    email = r['Email']
    first_name = r['First Name']
    last_name = r['Last Name']
    phone = r['Phone Number']
    company = r['Company Name']
    address = r['Address']

    print(first_name)

    # LOGIN
    print("Writing role...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelRole']")
    textbox.clear()
    textbox.send_keys(role)
    # time.sleep(0.5)

    print("Writing email...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelEmail']")
    textbox.clear()
    textbox.send_keys(email)
    # time.sleep(0.5)

    print("Writing first name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelFirstName']")
    textbox.clear()
    textbox.send_keys(first_name)
    # time.sleep(0.5)

    print("Writing last name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelLastName']")
    textbox.clear()
    textbox.send_keys(last_name)
    # time.sleep(0.5)

    print("Writing phone...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelPhone']")
    textbox.clear()
    textbox.send_keys(phone)
    # time.sleep(0.5)

    print("Writing address...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelAddress']")
    textbox.clear()
    textbox.send_keys(address)
    # time.sleep(0.5)

    print("Writing company...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelCompanyName']")
    textbox.clear()
    textbox.send_keys(company)
    # time.sleep(0.5)

    print('Submit...')
    botao = driver.find_element(By.XPATH, "//input[@type='submit']")
    botao.click()
    time.sleep(0.5)

print('Processo finalizado')

driver.quit()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First Name       10 non-null     object
#  1   Last Name        10 non-null     object
#  2   Company Name     10 non-null     object
#  3   Role in Company  10 non-null     object
#  4   Address          10 non-null     object
#  5   Email            10 non-null     object
#  6   Phone Number     10 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes
# None
# Iniciando nosso robô...
#
# Acessando site...
# Starting...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Last Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 28
#      26 email = r['Email']
#      27 first_name = r['First Name']
# ---> 28 last_name = r['Last Name']
#      29 phone = r['Phone Number']
#      30 company = r['Company Name']
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Last Name'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# Atribuição de Variaveis
site = "http://rpachallenge.com/"

arquivo = '/home/adriana/PythonADR/challenge.xlsx'

df_registros = pd.read_excel(arquivo)

print(df_registros.info())

driver = webdriver.Firefox()
print("Iniciando nosso robô...\n")
print("Acessando site...")
driver.get(site)

print('Starting...')
botao = driver.find_element(By.XPATH, "//button[@class='waves-effect col s12 m12 l12 btn-large uiColorButton']")
botao.click()
time.sleep(2)

for i, r in df_registros.iterrows():
    role = r['Role in Company']
    email = r['Email']
    first_name = r['First Name']
    last_name = r['Last Name ']  # Substitua 'Sobrenome' pelo nome correto da coluna
    phone = r['Phone Number']
    company = r['Company Name']
    address = r['Address']

    print(first_name)

    # LOGIN
    print("Writing role...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelRole']")
    textbox.clear()
    textbox.send_keys(role)
    #time.sleep(0.5)

    print("Writing email...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelEmail']")
    textbox.clear()
    textbox.send_keys(email)
    #time.sleep(0.5)

    print("Writing first name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelFirstName']")
    textbox.clear()
    textbox.send_keys(first_name)
    #time.sleep(0.5)

    print("Writing last name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelLastName']")
    textbox.clear()
    textbox.send_keys(last_name)
    #time.sleep(0.5)

    print("Writing phone...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelPhone']")
    textbox.clear()
    textbox.send_keys(phone)
    #time.sleep(0.5)

    print("Writing address...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelAddress']")
    textbox.clear()
    textbox.send_keys(address)
    #time.sleep(0.5)

    print("Writing company...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelCompanyName']")
    textbox.clear()
    textbox.send_keys(company)
    #time.sleep(0.5)

    print('Submit...')
    botao = driver.find_element(By.XPATH, "//input[@type='submit']")
    botao.click()
    time.sleep(0.5)

print('Processo finalizado')

driver.quit()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First Name       10 non-null     object
#  1   Last Name        10 non-null     object
#  2   Company Name     10 non-null     object
#  3   Role in Company  10 non-null     object
#  4   Address          10 non-null     object
#  5   Email            10 non-null     object
#  6   Phone Number     10 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes
# None
# Iniciando nosso robô...
#
# Acessando site...
# Starting...
# John
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jane
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Albert
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michael
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Doug
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jessie
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stan
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michelle
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stacy
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Lara
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Processo finalizado

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# Atribuição de Variaveis
site = "http://rpachallenge.com/"

arquivo = '/home/adriana/PythonADR/challenge.xlsx'

df_registros = pd.read_excel(arquivo)

print(df_registros.info())

driver = webdriver.Firefox()
print("Iniciando nosso robô...\n")
print("Acessando site...")
driver.get(site)

print('Starting...')
botao = driver.find_element(By.XPATH, "//button[@class='waves-effect col s12 m12 l12 btn-large uiColorButton']")
botao.click()
time.sleep(2)

for i, r in df_registros.iterrows():
    role = r['Role in Company']
    email = r['Email']
    first_name = r['First Name']
    last_name = r['Last Name ']  # Substitua 'Sobrenome' pelo nome correto da coluna
    phone = r['Phone Number']
    company = r['Company Name']
    address = r['Address']

    print(first_name)

    # LOGIN
    print("Writing role...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelRole']")
    textbox.clear()
    textbox.send_keys(role)
    #time.sleep(0.5)

    print("Writing email...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelEmail']")
    textbox.clear()
    textbox.send_keys(email)
    #time.sleep(0.5)

    print("Writing first name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelFirstName']")
    textbox.clear()
    textbox.send_keys(first_name)
    #time.sleep(0.5)

    print("Writing last name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelLastName']")
    textbox.clear()
    textbox.send_keys(last_name)
    #time.sleep(0.5)

    print("Writing phone...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelPhone']")
    textbox.clear()
    textbox.send_keys(phone)
    #time.sleep(0.5)

    print("Writing address...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelAddress']")
    textbox.clear()
    textbox.send_keys(address)
    #time.sleep(0.5)

    print("Writing company...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelCompanyName']")
    textbox.clear()
    textbox.send_keys(company)
    #time.sleep(0.5)

    print('Submit...')
    botao = driver.find_element(By.XPATH, "//input[@type='submit']")
    botao.click()
    time.sleep(0.3)

print('Processo finalizado')

driver.quit()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First Name       10 non-null     object
#  1   Last Name        10 non-null     object
#  2   Company Name     10 non-null     object
#  3   Role in Company  10 non-null     object
#  4   Address          10 non-null     object
#  5   Email            10 non-null     object
#  6   Phone Number     10 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes
# None
# Iniciando nosso robô...
#
# Acessando site...
# Starting...
# John
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jane
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Albert
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michael
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Doug
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jessie
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stan
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michelle
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stacy
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Lara
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Processo finalizado

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# Atribuição de Variaveis
site = "http://rpachallenge.com/"

arquivo = '/home/adriana/PythonADR/challenge.xlsx'

df_registros = pd.read_excel(arquivo)

print(df_registros.info())

driver = webdriver.Firefox()
print("Iniciando nosso robô...\n")
print("Acessando site...")
driver.get(site)

print('Starting...')
botao = driver.find_element(By.XPATH, "//button[@class='waves-effect col s12 m12 l12 btn-large uiColorButton']")
botao.click()
time.sleep(2)

for i, r in df_registros.iterrows():
    role = r['Role in Company']
    email = r['Email']
    first_name = r['First Name']
    last_name = r['Last Name ']  # Substitua 'Sobrenome' pelo nome correto da coluna
    phone = r['Phone Number']
    company = r['Company Name']
    address = r['Address']

    print(first_name)

    # LOGIN
    print("Writing role...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelRole']")
    textbox.clear()
    textbox.send_keys(role)
    #time.sleep(0.5)

    print("Writing email...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelEmail']")
    textbox.clear()
    textbox.send_keys(email)
    #time.sleep(0.5)

    print("Writing first name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelFirstName']")
    textbox.clear()
    textbox.send_keys(first_name)
    #time.sleep(0.5)

    print("Writing last name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelLastName']")
    textbox.clear()
    textbox.send_keys(last_name)
    #time.sleep(0.5)

    print("Writing phone...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelPhone']")
    textbox.clear()
    textbox.send_keys(phone)
    #time.sleep(0.5)

    print("Writing address...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelAddress']")
    textbox.clear()
    textbox.send_keys(address)
    #time.sleep(0.5)

    print("Writing company...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelCompanyName']")
    textbox.clear()
    textbox.send_keys(company)
    #time.sleep(0.5)

    print('Submit...')
    botao = driver.find_element(By.XPATH, "//input[@type='submit']")
    botao.click()
    time.sleep(0.3)

print('Processo finalizado')

driver.quit()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First Name       10 non-null     object
#  1   Last Name        10 non-null     object
#  2   Company Name     10 non-null     object
#  3   Role in Company  10 non-null     object
#  4   Address          10 non-null     object
#  5   Email            10 non-null     object
#  6   Phone Number     10 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes
# None
# Iniciando nosso robô...
#
# Acessando site...
# Starting...
# John
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jane
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Albert
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michael
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Doug
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jessie
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stan
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michelle
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stacy
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Lara
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Processo finalizado

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# Atribuição de Variaveis
site = "http://rpachallenge.com/"

arquivo = '/home/adriana/PythonADR/challenge.xlsx'

df_registros = pd.read_excel(arquivo)

print(df_registros.info())

driver = webdriver.Firefox()
print("Iniciando nosso robô...\n")
print("Acessando site...")
driver.get(site)

print('Starting...')
botao = driver.find_element(By.XPATH, "//button[@class='waves-effect col s12 m12 l12 btn-large uiColorButton']")
botao.click()
time.sleep(2)

for i, r in df_registros.iterrows():
    role = r['Role in Company']
    email = r['Email']
    first_name = r['First Name']
    last_name = r['Last Name ']  # Substitua 'Sobrenome' pelo nome correto da coluna
    phone = r['Phone Number']
    company = r['Company Name']
    address = r['Address']

    print(first_name)

    # LOGIN
    print("Writing role...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelRole']")
    textbox.clear()
    textbox.send_keys(role)
    #time.sleep(0.2)

    print("Writing email...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelEmail']")
    textbox.clear()
    textbox.send_keys(email)
    #time.sleep(0.2)

    print("Writing first name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelFirstName']")
    textbox.clear()
    textbox.send_keys(first_name)
    #time.sleep(0.2)

    print("Writing last name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelLastName']")
    textbox.clear()
    textbox.send_keys(last_name)
    #time.sleep(0.2

    print("Writing phone...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelPhone']")
    textbox.clear()
    textbox.send_keys(phone)
    #time.sleep(0.2)

    print("Writing address...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelAddress']")
    textbox.clear()
    textbox.send_keys(address)
    #time.sleep(0.2)

    print("Writing company...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelCompanyName']")
    textbox.clear()
    textbox.send_keys(company)
    #time.sleep(0.2)

    print('Submit...')
    botao = driver.find_element(By.XPATH, "//input[@type='submit']")
    botao.click()
    time.sleep(0.2)

print('Processo finalizado')

driver.quit()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First Name       10 non-null     object
#  1   Last Name        10 non-null     object
#  2   Company Name     10 non-null     object
#  3   Role in Company  10 non-null     object
#  4   Address          10 non-null     object
#  5   Email            10 non-null     object
#  6   Phone Number     10 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes
# None
# Iniciando nosso robô...
#
# Acessando site...
# Starting...
# John
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jane
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Albert
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michael
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Doug
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jessie
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stan
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michelle
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stacy
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Lara
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Processo finalizado

# %%
# Este código automatiza o preenchimento de um formulário em um site usando o Selenium WebDriver.
# Autor: Adriana Almeida

from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# Atribuição de Variaveis
site = "http://rpachallenge.com/"

arquivo = '/home/adriana/PythonADR/challenge.xlsx'

#exibe um resumo dos dados,

df_registros = pd.read_excel(arquivo)

#Imprime informações sobre o DataFrame 

print(df_registros.info())

#inicializa o driver do Firefox usando o Selenium WebDriver.

driver = webdriver.Firefox()

#conexão com o site 
print("Iniciando nosso robô...\n")
print("Acessando site...")
driver.get(site)

print('Starting...')
botao = driver.find_element(By.XPATH, "//button[@class='waves-effect col s12 m12 l12 btn-large uiColorButton']")
botao.click()
time.sleep(2)

#loop que percorre cada linha do DataFrame 

for i, r in df_registros.iterrows():
    role = r['Role in Company']
    email = r['Email']
    first_name = r['First Name']
    last_name = r['Last Name '] 
    phone = r['Phone Number']
    company = r['Company Name']
    address = r['Address']
    
    #Identificando campo no DOM da página usando XPath.

    print(first_name)

    # LOGIN
    print("Writing role...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelRole']")
    textbox.clear()
    textbox.send_keys(role)
    #time.sleep(0.2)

    print("Writing email...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelEmail']")
    textbox.clear()
    textbox.send_keys(email)
    #time.sleep(0.2)

    print("Writing first name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelFirstName']")
    textbox.clear()
    textbox.send_keys(first_name)
    #time.sleep(0.2)

    print("Writing last name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelLastName']")
    textbox.clear()
    textbox.send_keys(last_name)
    #time.sleep(0.2

    print("Writing phone...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelPhone']")
    textbox.clear()
    textbox.send_keys(phone)
    #time.sleep(0.2)

    print("Writing address...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelAddress']")
    textbox.clear()
    textbox.send_keys(address)
    #time.sleep(0.2)

    print("Writing company...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelCompanyName']")
    textbox.clear()
    textbox.send_keys(company)
    #time.sleep(0.2)

    print('Submit...')
    botao = driver.find_element(By.XPATH, "//input[@type='submit']")
    botao.click()
    time.sleep(0.2)

print('Processo finalizado')

driver.quit()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First Name       10 non-null     object
#  1   Last Name        10 non-null     object
#  2   Company Name     10 non-null     object
#  3   Role in Company  10 non-null     object
#  4   Address          10 non-null     object
#  5   Email            10 non-null     object
#  6   Phone Number     10 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes
# None
# Iniciando nosso robô...
#
# Acessando site...
# Starting...
# John
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jane
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Albert
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michael
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Doug
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jessie
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stan
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michelle
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stacy
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Lara
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Processo finalizado

# %%
# Este código automatiza o preenchimento de um formulário em um site usando o Selenium WebDriver.
# Autor: Adriana Almeida

from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# Atribuição de Variaveis
site = "http://rpachallenge.com/"

arquivo = '/home/adriana/PythonADR/challenge.xlsx'

#exibe um resumo dos dados,

df_registros = pd.read_excel(arquivo)

#Imprime informações sobre o DataFrame 

print(df_registros.info())

#inicializa o driver do Firefox usando o Selenium WebDriver.

driver = webdriver.Firefox()

#conexão com o site 
print("Iniciando nosso robô...\n")
print("Acessando site...")
driver.get(site)

print('Starting...')
botao = driver.find_element(By.XPATH, "//button[@class='waves-effect col s12 m12 l12 btn-large uiColorButton']")
botao.click()
time.sleep(2)

#loop que percorre cada linha do DataFrame 

for i, r in df_registros.iterrows():
    role = r['Role in Company']
    email = r['Email']
    first_name = r['First Name']
    last_name = r['Last Name '] 
    phone = r['Phone Number']
    company = r['Company Name']
    address = r['Address']
    
    #Identificando campo no DOM da página usando XPath.

    print(first_name)

    # LOGIN
    print("Writing role...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelRole']")
    textbox.clear()
    textbox.send_keys(role)
    #time.sleep(0.2)

    print("Writing email...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelEmail']")
    textbox.clear()
    textbox.send_keys(email)
    #time.sleep(0.2)

    print("Writing first name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelFirstName']")
    textbox.clear()
    textbox.send_keys(first_name)
    #time.sleep(0.2)

    print("Writing last name...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelLastName']")
    textbox.clear()
    textbox.send_keys(last_name)
    #time.sleep(0.2

    print("Writing phone...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelPhone']")
    textbox.clear()
    textbox.send_keys(phone)
    #time.sleep(0.2)

    print("Writing address...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelAddress']")
    textbox.clear()
    textbox.send_keys(address)
    #time.sleep(0.2)

    print("Writing company...")
    textbox = driver.find_element(By.XPATH, "//input[@ng-reflect-name='labelCompanyName']")
    textbox.clear()
    textbox.send_keys(company)
    #time.sleep(0.2)

    print('Submit...')
    botao = driver.find_element(By.XPATH, "//input[@type='submit']")
    botao.click()
    time.sleep(0.2)

print('Processo finalizado')

driver.quit()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First Name       10 non-null     object
#  1   Last Name        10 non-null     object
#  2   Company Name     10 non-null     object
#  3   Role in Company  10 non-null     object
#  4   Address          10 non-null     object
#  5   Email            10 non-null     object
#  6   Phone Number     10 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes
# None
# Iniciando nosso robô...
#
# Acessando site...
# Starting...
# John
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jane
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Albert
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michael
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Doug
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Jessie
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stan
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Michelle
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Stacy
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Lara
# Writing role...
# Writing email...
# Writing first name...
# Writing last name...
# Writing phone...
# Writing address...
# Writing company...
# Submit...
# Processo finalizado
